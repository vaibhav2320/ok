# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         75.0             90             64               75            2019
# 1         74.0             86             79               99            2018
# 2         65.0             80             69               97            2021
# 3         64.0             79             76               77            2020
# 4         95.0             76             63               97            2018
# 5         63.0             82             63               86            2018
# 6          NaN             92             80               98            2019
# 7         79.0             86             62               96            2019
# 8         63.0             92             70               84            2019
# 9         68.0             77             64               78            2020
# 10        65.0             84             72               80            2018
# 11        80.0             76             63               91            2021
# 12        72.0             80             75               95            2018
# 13        78.0             85             78               83            2020
# 14        77.0             84             72               95            2021
# 15        66.0             82             72               91            2019
# 16        36.0             80             62               87            2020
# 17         NaN             85             66              100            2018
# 18        64.0             83             60               85            2018
# 19        73.0             92             75               96            2019
# 20        77.0             90             68               87            2020
# 21        66.0             90             77               92            2021
# 22        64.0             95             77               76            2021
# 23        48.0             93             71               93            2020
# 24        77.0             85             75               83            2019
# 25        76.0             77             75               87            2020
# 26        60.0             89             80               89            2018
# 27        87.0             79             67               95            2019
# 28        74.0             87             78               87            2019
# 29        75.0             83             61               75            2019
#
#     Placement_Offer_Count  Region
# 0                       2    Pune
# 1                       3     NaN
# 2                       1  Nashik
# 3                       2    Pune
# 4                       3    Pune
# 5                       3     NaN
# 6                       3  Nashik
# 7                       3  Nashik
# 8                       2  Nashik
# 9                       2    Pune
# 10                      2  Nashik
# 11                      1    Pune
# 12                      3  Nashik
# 13                      2  Nashik
# 14                      3     NaN
# 15                      3  Nashik
# 16                      3     NaN
# 17                      3    Pune
# 18                      3     NaN
# 19                      3  Nashik
# 20                      3     NaN
# 21                      3     NaN
# 22                      2    Pune
# 23                      3     NaN
# 24                      2     NaN
# 25                      3    Pune
# 26                      1    Pune
# 27                      3  Nashik
# 28                      3     NaN
# 29                      1     NaN

# %%
df.isnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6         True          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# 11       False          False          False            False           False
# 12       False          False          False            False           False
# 13       False          False          False            False           False
# 14       False          False          False            False           False
# 15       False          False          False            False           False
# 16       False          False          False            False           False
# 17        True          False          False            False           False
# 18       False          False          False            False           False
# 19       False          False          False            False           False
# 20       False          False          False            False           False
# 21       False          False          False            False           False
# 22       False          False          False            False           False
# 23       False          False          False            False           False
# 24       False          False          False            False           False
# 25       False          False          False            False           False
# 26       False          False          False            False           False
# 27       False          False          False            False           False
# 28       False          False          False            False           False
# 29       False          False          False            False           False
#
#     Placement_Offer_Count  Region
# 0                   False   False
# 1                   False    True
# 2                   False   False
# 3                   False   False
# 4                   False   False
# 5                   False    True
# 6                   False   False
# 7                   False   False
# 8                   False   False
# 9                   False   False
# 10                  False   False
# 11                  False   False
# 12                  False   False
# 13                  False   False
# 14                  False    True
# 15                  False   False
# 16                  False    True
# 17                  False   False
# 18                  False    True
# 19                  False   False
# 20                  False    True
# 21                  False    True
# 22                  False   False
# 23                  False    True
# 24                  False    True
# 25                  False   False
# 26                  False   False
# 27                  False   False
# 28                  False    True
# 29                  False    True

# %%
series = pd.isnull(df["Math_Score"])
series
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: Math_Score, dtype: bool

# %%
m_v=df['Math_Score'].mean()
df['Math_Score'].fillna(value=m_v, inplace=True)
df[series]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 6    70.035714             92             80               98            2019
# 17   70.035714             85             66              100            2018
#
#     Placement_Offer_Count  Region
# 6                       3  Nashik
# 17                      3    Pune

# %%
ndf=df.dropna()
ndf
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    75.000000             90             64               75            2019
# 2    65.000000             80             69               97            2021
# 3    64.000000             79             76               77            2020
# 4    95.000000             76             63               97            2018
# 6    70.035714             92             80               98            2019
# 7    79.000000             86             62               96            2019
# 8    63.000000             92             70               84            2019
# 9    68.000000             77             64               78            2020
# 10   65.000000             84             72               80            2018
# 11   80.000000             76             63               91            2021
# 12   72.000000             80             75               95            2018
# 13   78.000000             85             78               83            2020
# 15   66.000000             82             72               91            2019
# 17   70.035714             85             66              100            2018
# 19   73.000000             92             75               96            2019
# 22   64.000000             95             77               76            2021
# 25   76.000000             77             75               87            2020
# 26   60.000000             89             80               89            2018
# 27   87.000000             79             67               95            2019
#
#     Placement_Offer_Count  Region
# 0                       2    Pune
# 2                       1  Nashik
# 3                       2    Pune
# 4                       3    Pune
# 6                       3  Nashik
# 7                       3  Nashik
# 8                       2  Nashik
# 9                       2    Pune
# 10                      2  Nashik
# 11                      1    Pune
# 12                      3  Nashik
# 13                      2  Nashik
# 15                      3  Nashik
# 17                      3    Pune
# 19                      3  Nashik
# 22                      2    Pune
# 25                      3    Pune
# 26                      1    Pune
# 27                      3  Nashik

# %%
col = ['Math_Score', 'Reading_Score' , 'Writing_Score','Placement_Score']
df.boxplot(col)
plt.show()

# %%
np.where(df['Math_Score']>80)
# Out:
# (array([ 4, 27], dtype=int32),)

# %%
np.where(df['Reading_Score']<80)
# Out:
# (array([ 3,  4,  9, 11, 25, 27], dtype=int32),)

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['Placement_Score'], df['Placement_Offer_Count'])
ax.set_ylabel('Placement Offers')
ax.set_xlabel('Placement Score')
plt.show()

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['Math_Score']))
z
# Out:
# 0     4.616549e-01
# 1     3.686597e-01
# 2     4.682975e-01
# 3     5.612927e-01
# 4     2.321560e+00
# 5     6.542879e-01
# 6     1.321542e-15
# 7     8.336359e-01
# 8     6.542879e-01
# 9     1.893117e-01
# 10    4.682975e-01
# 11    9.266311e-01
# 12    1.826692e-01
# 13    7.406407e-01
# 14    6.476454e-01
# 15    3.753022e-01
# 16    3.165159e+00
# 17    1.321542e-15
# 18    5.612927e-01
# 19    2.756645e-01
# 20    6.476454e-01
# 21    3.753022e-01
# 22    5.612927e-01
# 23    2.049217e+00
# 24    6.476454e-01
# 25    5.546502e-01
# 26    9.332736e-01
# 27    1.577598e+00
# 28    3.686597e-01
# 29    4.616549e-01
# Name: Math_Score, dtype: float64

# %%
threshold = 0.18
sample_outliers = np.where(z <threshold)
sample_outliers
# Out:
# (array([ 6, 17], dtype=int32),)

# %%
sorted_rscore= sorted(df['Reading_Score'])
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 80.0 89.75

# %%
IQR = q3-q1
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 65.375 104.375

# %%
r_outliers = []
for i in sorted_rscore:
    if (i<lwr_bound or i>upr_bound):
        r_outliers.append(i)
print(r_outliers)
# Out:
# []

# %%
median=np.median(sorted_rscore)
refined_df=df
refined_df['Reading_Score'] = np.where(refined_df['Reading_Score'] >upr_bound, median,refined_df['Reading_Score'])
refined_df['Reading Score'] = np.where(refined_df['Reading_Score'] <lwr_bound, median,refined_df['Reading_Score'])
refined_df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    75.000000           90.0             64               75            2019
# 1    74.000000           86.0             79               99            2018
# 2    65.000000           80.0             69               97            2021
# 3    64.000000           79.0             76               77            2020
# 4    95.000000           76.0             63               97            2018
# 5    63.000000           82.0             63               86            2018
# 6    70.035714           92.0             80               98            2019
# 7    79.000000           86.0             62               96            2019
# 8    63.000000           92.0             70               84            2019
# 9    68.000000           77.0             64               78            2020
# 10   65.000000           84.0             72               80            2018
# 11   80.000000           76.0             63               91            2021
# 12   72.000000           80.0             75               95            2018
# 13   78.000000           85.0             78               83            2020
# 14   77.000000           84.0             72               95            2021
# 15   66.000000           82.0             72               91            2019
# 16   36.000000           80.0             62               87            2020
# 17   70.035714           85.0             66              100            2018
# 18   64.000000           83.0             60               85            2018
# 19   73.000000           92.0             75               96            2019
# 20   77.000000           90.0             68               87            2020
# 21   66.000000           90.0             77               92            2021
# 22   64.000000           95.0             77               76            2021
# 23   48.000000           93.0             71               93            2020
# 24   77.000000           85.0             75               83            2019
# 25   76.000000           77.0             75               87            2020
# 26   60.000000           89.0             80               89            2018
# 27   87.000000           79.0             67               95            2019
# 28   74.000000           87.0             78               87            2019
# 29   75.000000           83.0             61               75            2019
#
#     Placement_Offer_Count  Region  Reading Score
# 0                       2    Pune           90.0
# 1                       3     NaN           86.0
# 2                       1  Nashik           80.0
# 3                       2    Pune           79.0
# 4                       3    Pune           76.0
# 5                       3     NaN           82.0
# 6                       3  Nashik           92.0
# 7                       3  Nashik           86.0
# 8                       2  Nashik           92.0
# 9                       2    Pune           77.0
# 10                      2  Nashik           84.0
# 11                      1    Pune           76.0
# 12                      3  Nashik           80.0
# 13                      2  Nashik           85.0
# 14                      3     NaN           84.0
# 15                      3  Nashik           82.0
# 16                      3     NaN           80.0
# 17                      3    Pune           85.0
# 18                      3     NaN           83.0
# 19                      3  Nashik           92.0
# 20                      3     NaN           90.0
# 21                      3     NaN           90.0
# 22                      2    Pune           95.0
# 23                      3     NaN           93.0
# 24                      2     NaN           85.0
# 25                      3    Pune           77.0
# 26                      1    Pune           89.0
# 27                      3  Nashik           79.0
# 28                      3     NaN           87.0
# 29                      1     NaN           83.0

# %%
col = ['Reading_Score']
refined_df.boxplot(col)
plt.show()

# %%
refined_df['Math_Score'].plot(kind = 'hist')
plt.show()

# %%
df['log_math'] = np.log10(df['Math_Score'])
df['log_math'].plot(kind = 'hist')
plt.show()
